# %% [markdown]
# # **`In The name of God!`**

# %% [markdown]
# Link to the Kaggle dataset:
#
# [Large Corpus of Persian Poems](https://www.kaggle.com/datasets/aminghd/large-corpus-of-farsi-poems)

# %% [markdown]
# while there are lots of Persian poems in this data source, we are going to just use Khayyam Poems for training our GPT model.

# %%
# %cp /content/drive/MyDrive/GenAI/NanoGPT_Persian/khayyam_norm.txt .

# %%
# installing required packages and libraries
# %%capture
# !pip install tiktoken

# %%
import os
import torch
import math
import inspect
import requests
import tiktoken
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset

# %%
input_file_path = '/content/khayyam_norm.txt'

with open(input_file_path, 'r', encoding='utf-8') as f:
    data = f.read()
n = len(data)
train_data = data[:int(n*0.9)]
val_data = data[int(n*0.9):]

# encode with tiktoken gpt2 bpe
enc = tiktoken.get_encoding("gpt2")
train_ids = enc.encode_ordinary(train_data)
val_ids = enc.encode_ordinary(val_data)
print(f"train has {len(train_ids):,} tokens")
print(f"val has {len(val_ids):,} tokens")

# export to bin files
train_ids = np.array(train_ids, dtype=np.uint16)
val_ids = np.array(val_ids, dtype=np.uint16)
train_ids.tofile('train.bin')
val_ids.tofile('val.bin')
# Out:
# train has 39,069 tokens
# val has 4,374 tokens

# %%
def decode_sample(ids, sample_size):
    sample_ids = ids[:sample_size]
    sample_text = enc.decode(sample_ids.tolist())
    return sample_text

print("Training Data Sample:")
print(decode_sample(train_ids, sample_size=100))

print("\nValidation Data Sample:")
print(decode_sample(val_ids, sample_size=100))
# Out:
# Training Data Sample:
#
#
# برخیز و بیا بتا برای دل ما
# حل کن به جمال خویشتن مشکل ما
# یک کوزه شراب تا بهم نوش کن�
#
# Validation Data Sample:
#  را
# حالی خوش کن تو این دل سودا را
# می نوش به ماهتاب ای ماه که ماه
# بسیار بگردد و نیابد ما را
# ای

# %%
class GPTDataset(Dataset):
    def __init__(self, data, block_size):
        self.data = data
        self.block_size = block_size

    def __len__(self):
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        x = torch.tensor(self.data[idx:idx + self.block_size], dtype=torch.long)
        y = torch.tensor(self.data[idx + 1:idx + 1 + self.block_size], dtype=torch.long)
        return x, y

# Filtering function
def filter_indices(data, max_index):
    return [idx for idx in data if idx < max_index]

class LayerNorm(nn.Module):
    """ LayerNorm but with an optional bias. PyTorch doesn't support simply bias=False """

    def __init__(self, ndim, bias):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(ndim))
        self.bias = nn.Parameter(torch.zeros(ndim)) if bias else None

    def forward(self, input):
        return F.layer_norm(input, self.weight.shape, self.weight, self.bias, 1e-5)

class CausalSelfAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        # output projection
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        # regularization
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.dropout = config.dropout
        # flash attention make GPU go brrrrr but support is only in PyTorch >= 2.0
        self.flash = hasattr(torch.nn.functional, 'scaled_dot_product_attention')
        if not self.flash:
            print("WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0")
            # causal mask to ensure that attention is only applied to the left in the input sequence
            self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                        .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        q, k, v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)

        # causal self-attention; Self-attend: (B, nh, T, hs) x (B, nh, hs, T) -> (B, nh, T, T)
        if self.flash:
            # efficient attention using Flash Attention CUDA kernels
            y = torch.nn.functional.scaled_dot_product_attention(q, k, v, attn_mask=None, dropout_p=self.dropout if self.training else 0, is_causal=True)
        else:
            # manual implementation of attention
            att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
            att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
            att = F.softmax(att, dim=-1)
            att = self.attn_dropout(att)
            y = att @ v # (B, nh, T, T) x (B, nh, T, hs) -> (B, nh, T, hs)
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side

        # output projection
        y = self.resid_dropout(self.c_proj(y))
        return y

class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.c_fc    = nn.Linear(config.n_embd, 4 * config.n_embd, bias=config.bias)
        self.gelu    = nn.GELU()
        self.c_proj  = nn.Linear(4 * config.n_embd, config.n_embd, bias=config.bias)
        self.dropout = nn.Dropout(config.dropout)

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        x = self.dropout(x)
        return x

class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.ln_1 = LayerNorm(config.n_embd, bias=config.bias)
        self.attn = CausalSelfAttention(config)
        self.ln_2 = LayerNorm(config.n_embd, bias=config.bias)
        self.mlp = MLP(config)

    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlp(self.ln_2(x))
        return x

class GPT(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.vocab_size is not None
        assert config.block_size is not None
        self.config = config

        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd),
            wpe = nn.Embedding(config.block_size, config.n_embd),
            drop = nn.Dropout(config.dropout),
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f = LayerNorm(config.n_embd, bias=config.bias),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight  # Weight tying

        # Init all weights
        self.apply(self._init_weights)
        # Apply special scaled init to the residual projections, per GPT-2 paper
        for pn, p in self.named_parameters():
            if pn.endswith('c_proj.weight'):
                torch.nn.init.normal_(p, mean=0.0, std=0.02 / math.sqrt(2 * config.n_layer))

        # Report number of parameters
        print("number of parameters: %.2fM" % (self.get_num_params() / 1e6,))

    def get_num_params(self, non_embedding=True):
        n_params = sum(p.numel() for p in self.parameters())
        if non_embedding:
            n_params -= self.transformer.wpe.weight.numel()
        return n_params

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.config.block_size, f"Cannot forward sequence of length {t}, block size is only {self.config.block_size}"
        pos = torch.arange(0, t, dtype=torch.long, device=device)  # shape (t)

        # Forward the GPT model itself
        tok_emb = self.transformer.wte(idx)  # token embeddings of shape (b, t, n_embd)
        pos_emb = self.transformer.wpe(pos)  # position embeddings of shape (t, n_embd)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)

        if targets is not None:
            # If we are given some desired targets also calculate the loss
            logits = self.lm_head(x)
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
        else:
            # Inference-time mini-optimization: only forward the lm_head on the very last position
            logits = self.lm_head(x[:, [-1], :])  # note: using list [-1] to preserve the time dim
            loss = None

        return logits, loss

    def configure_optimizers(self, weight_decay, learning_rate, betas, device_type):
        # start with all of the candidate parameters
        param_dict = {pn: p for pn, p in self.named_parameters()}
        # filter out those that do not require grad
        param_dict = {pn: p for pn, p in param_dict.items() if p.requires_grad}
        # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
        # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
        decay_params = [p for n, p in param_dict.items() if p.dim() >= 2]
        nodecay_params = [p for n, p in param_dict.items() if p.dim() < 2]
        optim_groups = [
            {'params': decay_params, 'weight_decay': weight_decay},
            {'params': nodecay_params, 'weight_decay': 0.0}
        ]
        num_decay_params = sum(p.numel() for p in decay_params)
        num_nodecay_params = sum(p.numel() for p in nodecay_params)
        print(f"num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
        print(f"num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")
        # Create AdamW optimizer and use the fused version if it is available
        fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
        use_fused = fused_available and device_type == 'cuda'
        extra_args = dict(fused=True) if use_fused else dict()
        optimizer = torch.optim.AdamW(optim_groups, lr=learning_rate, betas=betas, **extra_args)
        print(f"using fused AdamW: {use_fused}")

        return optimizer

# %%
import math
import torch
from dataclasses import dataclass

@dataclass
class GPTConfig:
    block_size: int
    vocab_size: int
    n_layer: int
    n_head: int
    n_embd: int  # n_embd must be divisible by n_head
    dropout: float
    bias: bool

config = GPTConfig(
    block_size=8,
    vocab_size= max(max(train_ids), max(val_ids)) + 1,
    n_layer=4,
    n_head=4,
    n_embd=256,  # Ensure n_embd is divisible by n_head
    dropout=0.1,
    bias=True
)

model = GPT(config)
print(model)
# Out:
# number of parameters: 15.20M
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(47049, 256)
#     (wpe): Embedding(8, 256)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-3): 4 x Block(
#         (ln_1): LayerNorm()
#         (attn): CausalSelfAttention(
#           (c_attn): Linear(in_features=256, out_features=768, bias=True)
#           (c_proj): Linear(in_features=256, out_features=256, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm()
#         (mlp): MLP(
#           (c_fc): Linear(in_features=256, out_features=1024, bias=True)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=1024, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm()
#   )
#   (lm_head): Linear(in_features=256, out_features=47049, bias=False)
# )

# %%
train_dataset = GPTDataset(train_ids, config.block_size)
val_dataset = GPTDataset(val_ids, config.block_size)
gradient_accumulation_steps = 5 * 8
batch_size = 12

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)
optimizer = model.configure_optimizers(weight_decay=0.1,
                                       learning_rate=3e-4,
                                       betas=(0.9, 0.95),
                                       device_type=device)
# Out:
# num decayed parameter tensors: 18, with 15,192,320 parameters
# num non-decayed parameter tensors: 34, with 13,824 parameters
# using fused AdamW: True

# %%
decay_lr = True
warmup_iters = 2000
lr_decay_iters = 600000
min_lr = 6e-5
learning_rate = 3e-4

def get_lr(it):
    if it < warmup_iters:
        return learning_rate * it / warmup_iters
    if it > lr_decay_iters:
        return min_lr
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
    return min_lr + coeff * (learning_rate - min_lr)

def print_sample_as_text(x, y, enc, train_val):
    random_idx = random.randint(0, x.size(0) - 1)
    x_text = decode_data(x[random_idx], enc)
    y_text = decode_data(y[random_idx], enc)
    print("Random Sample as text from  ", train_val)
    print(f"x: {x_text}")
    print(f"y: {y_text}")
    print("-" * 50)

def decode_data(ids, enc):
    sample_ids = ids.tolist()
    sample_text = enc.decode(sample_ids)
    return sample_text

# %%
import random
def train(model, train_loader, val_loader, optimizer, config, epochs=1, gradient_accumulation_steps=1):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    for state in optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)

    model.train()
    iter_num = 0
    best_val_loss = float('inf')
    model.train()
    iter_num = 0
    best_val_loss = float('inf')

    for epoch in range(epochs):
        running_loss = 0.0
        for batch_idx, (x, y) in enumerate(train_loader):
            x, y = x.to(device), y.to(device)
            lr = get_lr(iter_num)
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr

            logits, loss = model(x, y)
            loss = loss / gradient_accumulation_steps
            loss.backward()

            if (batch_idx + 1) % gradient_accumulation_steps == 0:
                optimizer.step()
                optimizer.zero_grad()
                iter_num += 1

                running_loss += loss.item()
                if iter_num % 5 == 0:
                    avg_loss = running_loss / 5
                    print(f'Epoch {epoch+1}/{epochs}, Iteration {iter_num}, Avg Loss: {avg_loss:.4f}')

                    print_sample_as_text(x, y, enc,"Training")

                    running_loss = 0.0

        # Validation
        val_loss = evaluate(model, val_loader, device)
        print(f'Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss:.4f}')

        # Save the best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), 'best_model.pt')
            print(f'Saving model with validation loss: {val_loss:.4f}')

def evaluate(model, val_loader, device): # Add device as parameter
    model.eval()
    val_loss = 0
    random_sample_printed = False  # Flag to ensure only one sample is printed
    with torch.no_grad():
        for x, y in val_loader:
            x, y = x.to(device), y.to(device) # Move validation data to the same device
            logits, loss = model(x, y)
            val_loss += loss.item()
            # Print one random sample from the validation set
            if not random_sample_printed:
                print_sample_as_text(x, y, enc,"Validation")
                random_sample_printed = True
    val_loss /= len(val_loader)
    model.train()
    return val_loss

# %%
train(model,
      train_loader,
      val_loader,
      optimizer,
      config,
      epochs=100,
      gradient_accumulation_steps=gradient_accumulation_steps)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 47/100, Iteration 3770, Avg Loss: 0.0268
# Random Sample as text from   Training
# x: سمان قر�
# y: مان قری
# --------------------------------------------------
# Epoch 47/100, Iteration 3775, Avg Loss: 0.0272
# Random Sample as text from   Training
# x:  نشسته �
# y: �شسته ب
# --------------------------------------------------
# Epoch 47/100, Iteration 3780, Avg Loss: 0.0277
# Random Sample as text from   Training
# x: کی شد
#
# y: �ی شد
# ا
# --------------------------------------------------
# Epoch 47/100, Iteration 3785, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: ه خر و ک
# y:  خر و کو
# --------------------------------------------------
# Epoch 47/100, Iteration 3790, Avg Loss: 0.0269
# Random Sample as text from   Training
# x: ن زیر �
# y:  زیر گ
# --------------------------------------------------
# Epoch 47/100, Iteration 3795, Avg Loss: 0.0267
# Random Sample as text from   Training
# x: �ی نف�
# y: ی نفز
# --------------------------------------------------
# Epoch 47/100, Iteration 3800, Avg Loss: 0.0267
# Random Sample as text from   Training
# x:  به گرد
# y: �ه گرد �
# --------------------------------------------------
# Epoch 47/100, Iteration 3805, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: �ه نورو�
# y: ه نوروز
# --------------------------------------------------
# Random Sample as text from   Validation
# x: ی خوش
# y: � خوش �
# --------------------------------------------------
# Epoch 47/100, Validation Loss: 1.7460
# Epoch 48/100, Iteration 3810, Avg Loss: 0.0156
# Random Sample as text from   Training
# x:
# در کالب
# y: در کالبد
# --------------------------------------------------
# Epoch 48/100, Iteration 3815, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: ه اسلام و
# y:  اسلام و �
# --------------------------------------------------
# Epoch 48/100, Iteration 3820, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: �ند دری
# y: ند درین
# --------------------------------------------------
# Epoch 48/100, Iteration 3825, Avg Loss: 0.0265
# Random Sample as text from   Training
# x: اجرام ک
# y: �رام که
# --------------------------------------------------
# Epoch 48/100, Iteration 3830, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: � رخ لال
# y:  رخ لاله
# --------------------------------------------------
# Epoch 48/100, Iteration 3835, Avg Loss: 0.0265
# Random Sample as text from   Training
# x: کوزه �
# y: �وزه گ
# --------------------------------------------------
# Epoch 48/100, Iteration 3840, Avg Loss: 0.0269
# Random Sample as text from   Training
# x: شوقه ا�
# y: �وقه از
# --------------------------------------------------
# Epoch 48/100, Iteration 3845, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: ه آید ا�
# y:  آید از
# --------------------------------------------------
# Epoch 48/100, Iteration 3850, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: �لاف دل
# y: لاف دل �
# --------------------------------------------------
# Epoch 48/100, Iteration 3855, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: گ زمین
# y: � زمین
#
# --------------------------------------------------
# Epoch 48/100, Iteration 3860, Avg Loss: 0.0276
# Random Sample as text from   Training
# x: کن
# ای �
# y: �ن
# ای د
# --------------------------------------------------
# Epoch 48/100, Iteration 3865, Avg Loss: 0.0257
# Random Sample as text from   Training
# x:  اجل بس�
# y: اجل بسی
# --------------------------------------------------
# Epoch 48/100, Iteration 3870, Avg Loss: 0.0268
# Random Sample as text from   Training
# x: اخته ای
# y: �ته ای
#
# --------------------------------------------------
# Epoch 48/100, Iteration 3875, Avg Loss: 0.0281
# Random Sample as text from   Training
# x: ف قدح �
# y: � قدح ب
# --------------------------------------------------
# Epoch 48/100, Iteration 3880, Avg Loss: 0.0269
# Random Sample as text from   Training
# x: در کالبد
# y: ر کالبد�
# --------------------------------------------------
# Epoch 48/100, Iteration 3885, Avg Loss: 0.0265
# Random Sample as text from   Training
# x: �
# نه آمد
# y:
# نه آمدم
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  را
# حال�
# y: �ا
# حالی
# --------------------------------------------------
# Epoch 48/100, Validation Loss: 1.7481
# Epoch 49/100, Iteration 3890, Avg Loss: 0.0098
# Random Sample as text from   Training
# x: یخبران
# y: �خبران
# --------------------------------------------------
# Epoch 49/100, Iteration 3895, Avg Loss: 0.0267
# Random Sample as text from   Training
# x: ت خیز
# y:  خیز ا
# --------------------------------------------------
# Epoch 49/100, Iteration 3900, Avg Loss: 0.0268
# Random Sample as text from   Training
# x:  اجل بس�
# y: اجل بسی
# --------------------------------------------------
# Epoch 49/100, Iteration 3905, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: � و دو ملت
# y:  و دو ملت �
# --------------------------------------------------
# Epoch 49/100, Iteration 3910, Avg Loss: 0.0247
# Random Sample as text from   Training
# x: عد از من و
# y: د از من و �
# --------------------------------------------------
# Epoch 49/100, Iteration 3915, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: �نان ای
# y: نان این
# --------------------------------------------------
# Epoch 49/100, Iteration 3920, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: م جمم ول�
# y:  جمم ولی
# --------------------------------------------------
# Epoch 49/100, Iteration 3925, Avg Loss: 0.0260
# Random Sample as text from   Training
# x:  چنین �
# y: چنین ج
# --------------------------------------------------
# Epoch 49/100, Iteration 3930, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: ند
# بربا�
# y: د
# بربای
# --------------------------------------------------
# Epoch 49/100, Iteration 3935, Avg Loss: 0.0274
# Random Sample as text from   Training
# x:  پدید ا�
# y: �دید اس
# --------------------------------------------------
# Epoch 49/100, Iteration 3940, Avg Loss: 0.0270
# Random Sample as text from   Training
# x: ری
# ای �
# y: ی
# ای آ
# --------------------------------------------------
# Epoch 49/100, Iteration 3945, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: رده هزا
# y: ده هزار
# --------------------------------------------------
# Epoch 49/100, Iteration 3950, Avg Loss: 0.0275
# Random Sample as text from   Training
# x: �ش کت �
# y: ش کت ب
# --------------------------------------------------
# Epoch 49/100, Iteration 3955, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: یم که
# y: �م که ا�
# --------------------------------------------------
# Epoch 49/100, Iteration 3960, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: ناک شده
# y: اک شده
#
# --------------------------------------------------
# Epoch 49/100, Iteration 3965, Avg Loss: 0.0266
# Random Sample as text from   Training
# x: � همه ک
# y:  همه کا
# --------------------------------------------------
# Random Sample as text from   Validation
# x: حالی خو
# y: �الی خو�
# --------------------------------------------------
# Epoch 49/100, Validation Loss: 1.7541
# Epoch 50/100, Iteration 3970, Avg Loss: 0.0051
# Random Sample as text from   Training
# x:  که ماه
#
# y: که ماه
# ب
# --------------------------------------------------
# Epoch 50/100, Iteration 3975, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: �اه صد ب
# y: اه صد به
# --------------------------------------------------
# Epoch 50/100, Iteration 3980, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: � ز خواب
# y:  ز خواب �
# --------------------------------------------------
# Epoch 50/100, Iteration 3985, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: ند
# فرما
# y: د
# فرما�
# --------------------------------------------------
# Epoch 50/100, Iteration 3990, Avg Loss: 0.0280
# Random Sample as text from   Training
# x: �ه جای �
# y: ه جای آ
# --------------------------------------------------
# Epoch 50/100, Iteration 3995, Avg Loss: 0.0269
# Random Sample as text from   Training
# x: ود شده و �
# y: د شده و ب
# --------------------------------------------------
# Epoch 50/100, Iteration 4000, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: ت همین �
# y:  همین خ
# --------------------------------------------------
# Epoch 50/100, Iteration 4005, Avg Loss: 0.0261
# Random Sample as text from   Training
# x:  تو
# قص
# y: �و
# قصد
# --------------------------------------------------
# Epoch 50/100, Iteration 4010, Avg Loss: 0.0266
# Random Sample as text from   Training
# x: ز شمار
#
# y: � شمار
# ب
# --------------------------------------------------
# Epoch 50/100, Iteration 4015, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: خور غم �
# y: �ور غم ج
# --------------------------------------------------
# Epoch 50/100, Iteration 4020, Avg Loss: 0.0267
# Random Sample as text from   Training
# x:  خونخوا
# y: �ونخوار
# --------------------------------------------------
# Epoch 50/100, Iteration 4025, Avg Loss: 0.0274
# Random Sample as text from   Training
# x: �ست به ا�
# y: ست به از
# --------------------------------------------------
# Epoch 50/100, Iteration 4030, Avg Loss: 0.0266
# Random Sample as text from   Training
# x: ین دشو
# y: �ن دشوا
# --------------------------------------------------
# Epoch 50/100, Iteration 4035, Avg Loss: 0.0262
# Random Sample as text from   Training
# x:  از او م�
# y: از او مث
# --------------------------------------------------
# Epoch 50/100, Iteration 4040, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: ه آن هر �
# y:  آن هر آ
# --------------------------------------------------
# Epoch 50/100, Iteration 4045, Avg Loss: 0.0268
# Random Sample as text from   Training
# x: است
# وز �
# y: �ت
# وز ص
# --------------------------------------------------
# Epoch 50/100, Iteration 4050, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: �ردن یا
# y: ردن یار
# --------------------------------------------------
# Random Sample as text from   Validation
# x: الی خوش
# y: ی خوش
# --------------------------------------------------
# Epoch 50/100, Validation Loss: 1.7621
# Epoch 51/100, Iteration 4055, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: اهد بر خ
# y: هد بر خن
# --------------------------------------------------
# Epoch 51/100, Iteration 4060, Avg Loss: 0.0257
# Random Sample as text from   Training
# x:  نتوان ب
# y: �توان بس
# --------------------------------------------------
# Epoch 51/100, Iteration 4065, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: چگونه
# y: �گونه �
# --------------------------------------------------
# Epoch 51/100, Iteration 4070, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: �فتگان
# y: فتگان
# --------------------------------------------------
# Epoch 51/100, Iteration 4075, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: �مشید
# y: مشید ا�
# --------------------------------------------------
# Epoch 51/100, Iteration 4080, Avg Loss: 0.0258
# Random Sample as text from   Training
# x: �ورشید
# y: ورشید
# --------------------------------------------------
# Epoch 51/100, Iteration 4085, Avg Loss: 0.0268
# Random Sample as text from   Training
# x: �ان روی
# y: ان روی
# --------------------------------------------------
# Epoch 51/100, Iteration 4090, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: ی دارد �
# y: � دارد ب
# --------------------------------------------------
# Epoch 51/100, Iteration 4095, Avg Loss: 0.0276
# Random Sample as text from   Training
# x: این دهر
# y: ین دهر م
# --------------------------------------------------
# Epoch 51/100, Iteration 4100, Avg Loss: 0.0272
# Random Sample as text from   Training
# x: ش خود ش
# y: � خود شر
# --------------------------------------------------
# Epoch 51/100, Iteration 4105, Avg Loss: 0.0268
# Random Sample as text from   Training
# x: اند
# سیم
# y: ند
# سیم و
# --------------------------------------------------
# Epoch 51/100, Iteration 4110, Avg Loss: 0.0267
# Random Sample as text from   Training
# x:  است هر �
# y: است هر آ
# --------------------------------------------------
# Epoch 51/100, Iteration 4115, Avg Loss: 0.0258
# Random Sample as text from   Training
# x: ید از غ
# y: �د از غر
# --------------------------------------------------
# Epoch 51/100, Iteration 4120, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: ان است ز
# y: ن است ز
# --------------------------------------------------
# Epoch 51/100, Iteration 4125, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: �مم ولی
# y: مم ولی �
# --------------------------------------------------
# Epoch 51/100, Iteration 4130, Avg Loss: 0.0255
# Random Sample as text from   Training
# x:  گردد د
# y: گردد در
# --------------------------------------------------
# Random Sample as text from   Validation
# x: � خوش �
# y:  خوش ک
# --------------------------------------------------
# Epoch 51/100, Validation Loss: 1.7558
# Epoch 52/100, Iteration 4135, Avg Loss: 0.0200
# Random Sample as text from   Training
# x:  نه بر د
# y: �ه بر دو
# --------------------------------------------------
# Epoch 52/100, Iteration 4140, Avg Loss: 0.0266
# Random Sample as text from   Training
# x: �
#  من ظاه
# y:
#  من ظاهر
# --------------------------------------------------
# Epoch 52/100, Iteration 4145, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: � شده
# بل
# y:  شده
# بلب
# --------------------------------------------------
# Epoch 52/100, Iteration 4150, Avg Loss: 0.0263
# Random Sample as text from   Training
# x:  قدیم
# �
# y: �دیم
# خ
# --------------------------------------------------
# Epoch 52/100, Iteration 4155, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: د و خاک م
# y:  و خاک م�
# --------------------------------------------------
# Epoch 52/100, Iteration 4160, Avg Loss: 0.0263
# Random Sample as text from   Training
# x:  کجا خ
# y: کجا خو
# --------------------------------------------------
# Epoch 52/100, Iteration 4165, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: � است
# من
# y:  است
# من م
# --------------------------------------------------
# Epoch 52/100, Iteration 4170, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: ی حور س
# y: � حور سر
# --------------------------------------------------
# Epoch 52/100, Iteration 4175, Avg Loss: 0.0266
# Random Sample as text from   Training
# x: ر این ش
# y:  این شو
# --------------------------------------------------
# Epoch 52/100, Iteration 4180, Avg Loss: 0.0275
# Random Sample as text from   Training
# x:
# کاو گ
# y: کاو گل
# --------------------------------------------------
# Epoch 52/100, Iteration 4185, Avg Loss: 0.0262
# Random Sample as text from   Training
# x:  که ز خ
# y: که ز خو
# --------------------------------------------------
# Epoch 52/100, Iteration 4190, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: از جهان و
# y: � جهان و م
# --------------------------------------------------
# Epoch 52/100, Iteration 4195, Avg Loss: 0.0265
# Random Sample as text from   Training
# x: ار دایم
# y: ر دایم
# --------------------------------------------------
# Epoch 52/100, Iteration 4200, Avg Loss: 0.0271
# Random Sample as text from   Training
# x:  از این
# y: از این �
# --------------------------------------------------
# Epoch 52/100, Iteration 4205, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: ار بیچ
# y: ر بیچا
# --------------------------------------------------
# Epoch 52/100, Iteration 4210, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: ن و تو
# چ
# y:  و تو
# چو
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  را
# حال�
# y: �ا
# حالی
# --------------------------------------------------
# Epoch 52/100, Validation Loss: 1.7715
# Epoch 53/100, Iteration 4215, Avg Loss: 0.0151
# Random Sample as text from   Training
# x: خنی از
# y: �نی از �
# --------------------------------------------------
# Epoch 53/100, Iteration 4220, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: �فت
# کا�
# y: فت
# کاز
# --------------------------------------------------
# Epoch 53/100, Iteration 4225, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: �ه سرشت
# y: ه سرشت
#
# --------------------------------------------------
# Epoch 53/100, Iteration 4230, Avg Loss: 0.0270
# Random Sample as text from   Training
# x: گم نکن
# y: �م نکن�
# --------------------------------------------------
# Epoch 53/100, Iteration 4235, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: ه شبنم �
# y:  شبنم گ
# --------------------------------------------------
# Epoch 53/100, Iteration 4240, Avg Loss: 0.0242
# Random Sample as text from   Training
# x: ا چرخ م
# y:  چرخ م�
# --------------------------------------------------
# Epoch 53/100, Iteration 4245, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: ان کوز
# y: ن کوزه
# --------------------------------------------------
# Epoch 53/100, Iteration 4250, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: رنیک ن
# y: نیک ن�
# --------------------------------------------------
# Epoch 53/100, Iteration 4255, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: �ر کار �
# y: ر کار ف
# --------------------------------------------------
# Epoch 53/100, Iteration 4260, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: ده
# در سا
# y: ه
# در سا�
# --------------------------------------------------
# Epoch 53/100, Iteration 4265, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: رشید ر
# y: شید ر�
# --------------------------------------------------
# Epoch 53/100, Iteration 4270, Avg Loss: 0.0280
# Random Sample as text from   Training
# x: اکت
# بر �
# y: کت
# بر س
# --------------------------------------------------
# Epoch 53/100, Iteration 4275, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: ت دارد
# ا�
# y:  دارد
# از
# --------------------------------------------------
# Epoch 53/100, Iteration 4280, Avg Loss: 0.0269
# Random Sample as text from   Training
# x:
# وز حاص
# y: وز حاصل
# --------------------------------------------------
# Epoch 53/100, Iteration 4285, Avg Loss: 0.0275
# Random Sample as text from   Training
# x:  شدند
# در
# y: �دند
# در �
# --------------------------------------------------
# Epoch 53/100, Iteration 4290, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: �ه آعشت
# y: ه آعشته
# --------------------------------------------------
# Random Sample as text from   Validation
# x: حالی خو
# y: �الی خو�
# --------------------------------------------------
# Epoch 53/100, Validation Loss: 1.7827
# Epoch 54/100, Iteration 4295, Avg Loss: 0.0094
# Random Sample as text from   Training
# x: ه است
# هر
# y:  است
# هر �
# --------------------------------------------------
# Epoch 54/100, Iteration 4300, Avg Loss: 0.0241
# Random Sample as text from   Training
# x:  را ز ک
# y: �ا ز کس
# --------------------------------------------------
# Epoch 54/100, Iteration 4305, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: ا او می
# y:  او می �
# --------------------------------------------------
# Epoch 54/100, Iteration 4310, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: �م و بی�
# y: م و بیش
# --------------------------------------------------
# Epoch 54/100, Iteration 4315, Avg Loss: 0.0253
# Random Sample as text from   Training
# x:  خواری
#
# y: �واری
# ا
# --------------------------------------------------
# Epoch 54/100, Iteration 4320, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: م بروی �
# y:  بروی د
# --------------------------------------------------
# Epoch 54/100, Iteration 4325, Avg Loss: 0.0249
# Random Sample as text from   Training
# x:  گرد
# بل
# y: گرد
# بلب
# --------------------------------------------------
# Epoch 54/100, Iteration 4330, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: �ر زمین
# y: ر زمین �
# --------------------------------------------------
# Epoch 54/100, Iteration 4335, Avg Loss: 0.0267
# Random Sample as text from   Training
# x: ر رفته �
# y:  رفته ر
# --------------------------------------------------
# Epoch 54/100, Iteration 4340, Avg Loss: 0.0251
# Random Sample as text from   Training
# x: یدون صد
# y: �دون صد �
# --------------------------------------------------
# Epoch 54/100, Iteration 4345, Avg Loss: 0.0268
# Random Sample as text from   Training
# x: اق عقل
# y: ق عقل و
# --------------------------------------------------
# Epoch 54/100, Iteration 4350, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: ا نگشا�
# y:  نگشاد
# --------------------------------------------------
# Epoch 54/100, Iteration 4355, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: �ا نسیه
# y: ا نسیه �
# --------------------------------------------------
# Epoch 54/100, Iteration 4360, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: � گل تا�
# y:  گل تاز
# --------------------------------------------------
# Epoch 54/100, Iteration 4365, Avg Loss: 0.0253
# Random Sample as text from   Training
# x:  بسفت
# ه
# y: �سفت
# هر
# --------------------------------------------------
# Epoch 54/100, Iteration 4370, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: شت
# دری
# y: �ت
# دریا�
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  را
# حال�
# y: �ا
# حالی
# --------------------------------------------------
# Epoch 54/100, Validation Loss: 1.7743
# Epoch 55/100, Iteration 4375, Avg Loss: 0.0050
# Random Sample as text from   Training
# x: ادندی ر
# y: �ندی رو
# --------------------------------------------------
# Epoch 55/100, Iteration 4380, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: �جان پا
# y: جان پا�
# --------------------------------------------------
# Epoch 55/100, Iteration 4385, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: که در خ
# y: �ه در خو
# --------------------------------------------------
# Epoch 55/100, Iteration 4390, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: ل مکن هم
# y:  مکن هم �
# --------------------------------------------------
# Epoch 55/100, Iteration 4395, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: کدو می �
# y: �دو می س
# --------------------------------------------------
# Epoch 55/100, Iteration 4400, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: ر چه می
# y:  چه می
# --------------------------------------------------
# Epoch 55/100, Iteration 4405, Avg Loss: 0.0265
# Random Sample as text from   Training
# x:  زد و خوا
# y: �د و خوار
# --------------------------------------------------
# Epoch 55/100, Iteration 4410, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: ر کاسه م
# y:  کاسه م�
# --------------------------------------------------
# Epoch 55/100, Iteration 4415, Avg Loss: 0.0260
# Random Sample as text from   Training
# x:  نرم نرم
# y: �رم نرم�
# --------------------------------------------------
# Epoch 55/100, Iteration 4420, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: ا به زن�
# y:  به زنی
# --------------------------------------------------
# Epoch 55/100, Iteration 4425, Avg Loss: 0.0273
# Random Sample as text from   Training
# x:  گرفت
#
# y: گرفت
# �
# --------------------------------------------------
# Epoch 55/100, Iteration 4430, Avg Loss: 0.0266
# Random Sample as text from   Training
# x:  تلخ
# خ
# y: �لخ
# خو
# --------------------------------------------------
# Epoch 55/100, Iteration 4435, Avg Loss: 0.0255
# Random Sample as text from   Training
# x: کن هم ب
# y: �ن هم ب�
# --------------------------------------------------
# Epoch 55/100, Iteration 4440, Avg Loss: 0.0258
# Random Sample as text from   Training
# x:  رفتگا
# y: �فتگان
# --------------------------------------------------
# Epoch 55/100, Iteration 4445, Avg Loss: 0.0258
# Random Sample as text from   Training
# x: �ه دو جا
# y: ه دو جام
# --------------------------------------------------
# Epoch 55/100, Iteration 4450, Avg Loss: 0.0255
# Random Sample as text from   Training
# x: کمیم
# �
# y: �میم
# آ
# --------------------------------------------------
# Epoch 55/100, Iteration 4455, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: �خوری �
# y: خوری ط
# --------------------------------------------------
# Random Sample as text from   Validation
# x: ا
# حالی �
# y:
# حالی خ
# --------------------------------------------------
# Epoch 55/100, Validation Loss: 1.8092
# Epoch 56/100, Iteration 4460, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: ه سرد
# اب
# y:  سرد
# ابر
# --------------------------------------------------
# Epoch 56/100, Iteration 4465, Avg Loss: 0.0255
# Random Sample as text from   Training
# x:  شیرین
# y: �یرین
# --------------------------------------------------
# Epoch 56/100, Iteration 4470, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: �شکاف
# y: شکافت
# --------------------------------------------------
# Epoch 56/100, Iteration 4475, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: ده است
# ب
# y: ه است
# با
# --------------------------------------------------
# Epoch 56/100, Iteration 4480, Avg Loss: 0.0253
# Random Sample as text from   Training
# x: � اهل به
# y:  اهل به�
# --------------------------------------------------
# Epoch 56/100, Iteration 4485, Avg Loss: 0.0258
# Random Sample as text from   Training
# x: �سریم
# ا
# y: سریم
# ا�
# --------------------------------------------------
# Epoch 56/100, Iteration 4490, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: قی چس
# y: �ی چست
# --------------------------------------------------
# Epoch 56/100, Iteration 4495, Avg Loss: 0.0272
# Random Sample as text from   Training
# x: نچه خو�
# y: چه خوش
# --------------------------------------------------
# Epoch 56/100, Iteration 4500, Avg Loss: 0.0251
# Random Sample as text from   Training
# x: �یشه د
# y: یشه د�
# --------------------------------------------------
# Epoch 56/100, Iteration 4505, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: بودیم و �
# y: ودیم و ن
# --------------------------------------------------
# Epoch 56/100, Iteration 4510, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: شت کرد
# y: �ت کرد
# --------------------------------------------------
# Epoch 56/100, Iteration 4515, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: �ور
# کا�
# y: ور
# کای
# --------------------------------------------------
# Epoch 56/100, Iteration 4520, Avg Loss: 0.0269
# Random Sample as text from   Training
# x: ایی هس
# y: یی هست
# --------------------------------------------------
# Epoch 56/100, Iteration 4525, Avg Loss: 0.0260
# Random Sample as text from   Training
# x:  را چو �
# y: �ا چو خ
# --------------------------------------------------
# Epoch 56/100, Iteration 4530, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: ش نماند
# y: � نماند
#
# --------------------------------------------------
# Epoch 56/100, Iteration 4535, Avg Loss: 0.0257
# Random Sample as text from   Training
# x:  سال
# صد �
# y: �ال
# صد س
# --------------------------------------------------
# Random Sample as text from   Validation
# x: ا
# حالی �
# y:
# حالی خ
# --------------------------------------------------
# Epoch 56/100, Validation Loss: 1.7754
# Epoch 57/100, Iteration 4540, Avg Loss: 0.0200
# Random Sample as text from   Training
# x: د
# گر مال �
# y:
# گر مال ن
# --------------------------------------------------
# Epoch 57/100, Iteration 4545, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: دنیا د�
# y: نیا دی
# --------------------------------------------------
# Epoch 57/100, Iteration 4550, Avg Loss: 0.0246
# Random Sample as text from   Training
# x: بر چرخ
# y: ر چرخ �
# --------------------------------------------------
# Epoch 57/100, Iteration 4555, Avg Loss: 0.0258
# Random Sample as text from   Training
# x:  آرامگه
# y: �رامگه
# --------------------------------------------------
# Epoch 57/100, Iteration 4560, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: �ای آرم
# y: ای آرم�
# --------------------------------------------------
# Epoch 57/100, Iteration 4565, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: پا بر س
# y: �ا بر سر
# --------------------------------------------------
# Epoch 57/100, Iteration 4570, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: ر عجبم �
# y:  عجبم ز
# --------------------------------------------------
# Epoch 57/100, Iteration 4575, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: شوقه ا�
# y: �وقه از
# --------------------------------------------------
# Epoch 57/100, Iteration 4580, Avg Loss: 0.0270
# Random Sample as text from   Training
# x: �نبر چر
# y: نبر چر�
# --------------------------------------------------
# Epoch 57/100, Iteration 4585, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: �وزه ش�
# y: وزه شک
# --------------------------------------------------
# Epoch 57/100, Iteration 4590, Avg Loss: 0.0258
# Random Sample as text from   Training
# x: ردمک چ
# y: دمک چ�
# --------------------------------------------------
# Epoch 57/100, Iteration 4595, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: کسته ا�
# y: �سته ای
# --------------------------------------------------
# Epoch 57/100, Iteration 4600, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: را
# خواه
# y: ا
# خواه�
# --------------------------------------------------
# Epoch 57/100, Iteration 4605, Avg Loss: 0.0269
# Random Sample as text from   Training
# x: لاک که
# y: اک که �
# --------------------------------------------------
# Epoch 57/100, Iteration 4610, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: ی مریم �
# y: � مریم خ
# --------------------------------------------------
# Epoch 57/100, Iteration 4615, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: �گراین
# y: گرایند
# --------------------------------------------------
# Random Sample as text from   Validation
# x: � خوش �
# y:  خوش ک
# --------------------------------------------------
# Epoch 57/100, Validation Loss: 1.7884
# Epoch 58/100, Iteration 4620, Avg Loss: 0.0150
# Random Sample as text from   Training
# x: ای کو
# y: ی کو �
# --------------------------------------------------
# Epoch 58/100, Iteration 4625, Avg Loss: 0.0246
# Random Sample as text from   Training
# x: �رین بس
# y: رین بسا�
# --------------------------------------------------
# Epoch 58/100, Iteration 4630, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: ی خوش �
# y: � خوش ب
# --------------------------------------------------
# Epoch 58/100, Iteration 4635, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: �اسه می
# y: اسه می ا�
# --------------------------------------------------
# Epoch 58/100, Iteration 4640, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: خ است ا�
# y: � است از
# --------------------------------------------------
# Epoch 58/100, Iteration 4645, Avg Loss: 0.0255
# Random Sample as text from   Training
# x: دا خواه�
# y: ا خواهی
# --------------------------------------------------
# Epoch 58/100, Iteration 4650, Avg Loss: 0.0252
# Random Sample as text from   Training
# x:  دست بد�
# y: �ست بدی
# --------------------------------------------------
# Epoch 58/100, Iteration 4655, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: دی بکا
# y: ی بکار
# --------------------------------------------------
# Epoch 58/100, Iteration 4660, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: � کاش �
# y:  کاش ک
# --------------------------------------------------
# Epoch 58/100, Iteration 4665, Avg Loss: 0.0265
# Random Sample as text from   Training
# x: ی رو
# د�
# y: � رو
# دی
# --------------------------------------------------
# Epoch 58/100, Iteration 4670, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: ه گفت و
# y:  گفت و�
# --------------------------------------------------
# Epoch 58/100, Iteration 4675, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: جوی
# بر
# y: �وی
# بر
# --------------------------------------------------
# Epoch 58/100, Iteration 4680, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: ت
# انگش
# y:
# انگشت
# --------------------------------------------------
# Epoch 58/100, Iteration 4685, Avg Loss: 0.0266
# Random Sample as text from   Training
# x: �ت
# گور�
# y: ت
# گوری
# --------------------------------------------------
# Epoch 58/100, Iteration 4690, Avg Loss: 0.0267
# Random Sample as text from   Training
# x:  ساختمی
# y: �اختمی
#
# --------------------------------------------------
# Epoch 58/100, Iteration 4695, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: وزه شک
# y: زه شکس
# --------------------------------------------------
# Random Sample as text from   Validation
# x:
# حالی خ
# y: حالی خو
# --------------------------------------------------
# Epoch 58/100, Validation Loss: 1.8135
# Epoch 59/100, Iteration 4700, Avg Loss: 0.0102
# Random Sample as text from   Training
# x: �
# وان ک
# y:
# وان کو
# --------------------------------------------------
# Epoch 59/100, Iteration 4705, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: �اک من و �
# y: اک من و ت
# --------------------------------------------------
# Epoch 59/100, Iteration 4710, Avg Loss: 0.0247
# Random Sample as text from   Training
# x: ن از ک�
# y:  از کج
# --------------------------------------------------
# Epoch 59/100, Iteration 4715, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: �زایند
# y: زایند �
# --------------------------------------------------
# Epoch 59/100, Iteration 4720, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: عیبم مک
# y: یبم مکن
# --------------------------------------------------
# Epoch 59/100, Iteration 4725, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: وی دری
# y: ی دریا
# --------------------------------------------------
# Epoch 59/100, Iteration 4730, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: وز عالم �
# y: ز عالم ش
# --------------------------------------------------
# Epoch 59/100, Iteration 4735, Avg Loss: 0.0258
# Random Sample as text from   Training
# x:  که مهتا�
# y: که مهتاب
# --------------------------------------------------
# Epoch 59/100, Iteration 4740, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: �ه کنم
# y: ه کنم �
# --------------------------------------------------
# Epoch 59/100, Iteration 4745, Avg Loss: 0.0264
# Random Sample as text from   Training
# x: ست راه د
# y: ت راه در
# --------------------------------------------------
# Epoch 59/100, Iteration 4750, Avg Loss: 0.0254
# Random Sample as text from   Training
# x:  کردم ب
# y: کردم بس
# --------------------------------------------------
# Epoch 59/100, Iteration 4755, Avg Loss: 0.0258
# Random Sample as text from   Training
# x: ان
# کانه
# y: ن
# کانهم
# --------------------------------------------------
# Epoch 59/100, Iteration 4760, Avg Loss: 0.0252
# Random Sample as text from   Training
# x:  پیشتر
# y: �یشتر
# --------------------------------------------------
# Epoch 59/100, Iteration 4765, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: بیزار �
# y: یزار ش
# --------------------------------------------------
# Epoch 59/100, Iteration 4770, Avg Loss: 0.0243
# Random Sample as text from   Training
# x: �هانی د
# y: هانی دا
# --------------------------------------------------
# Epoch 59/100, Iteration 4775, Avg Loss: 0.0252
# Random Sample as text from   Training
# x:  نبردند �
# y: �بردند ب
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  خوش ک
# y: �وش کن
# --------------------------------------------------
# Epoch 59/100, Validation Loss: 1.7929
# Epoch 60/100, Iteration 4780, Avg Loss: 0.0049
# Random Sample as text from   Training
# x: رزد هش
# y: زد هشد
# --------------------------------------------------
# Epoch 60/100, Iteration 4785, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: م
# سرمای
# y:
# سرمایه
# --------------------------------------------------
# Epoch 60/100, Iteration 4790, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: گذری
#
# y: �ذری
# �
# --------------------------------------------------
# Epoch 60/100, Iteration 4795, Avg Loss: 0.0246
# Random Sample as text from   Training
# x: ل به زبا
# y:  به زبان
# --------------------------------------------------
# Epoch 60/100, Iteration 4800, Avg Loss: 0.0253
# Random Sample as text from   Training
# x:  شدند
# آ
# y: �دند
# آن
# --------------------------------------------------
# Epoch 60/100, Iteration 4805, Avg Loss: 0.0260
# Random Sample as text from   Training
# x:  بحر وج
# y: �حر وجو
# --------------------------------------------------
# Epoch 60/100, Iteration 4810, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: �ی چست
# y: ی چست
#
# --------------------------------------------------
# Epoch 60/100, Iteration 4815, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: زان پی
# y: �ان پی�
# --------------------------------------------------
# Epoch 60/100, Iteration 4820, Avg Loss: 0.0257
# Random Sample as text from   Training
# x:  جگرها �
# y: �گرها خ
# --------------------------------------------------
# Epoch 60/100, Iteration 4825, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: �ند که �
# y: ند که ر
# --------------------------------------------------
# Epoch 60/100, Iteration 4830, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: � کوزه
# y:  کوزه �
# --------------------------------------------------
# Epoch 60/100, Iteration 4835, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: ت
# بیداد
# y:
# بیداد�
# --------------------------------------------------
# Epoch 60/100, Iteration 4840, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: یه گل �
# y: �ه گل ن
# --------------------------------------------------
# Epoch 60/100, Iteration 4845, Avg Loss: 0.0251
# Random Sample as text from   Training
# x: چون چر
# y: �ون چر�
# --------------------------------------------------
# Epoch 60/100, Iteration 4850, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: �وی شرا�
# y: وی شراب
# --------------------------------------------------
# Epoch 60/100, Iteration 4855, Avg Loss: 0.0268
# Random Sample as text from   Training
# x: �و هزار
# y: و هزار
# --------------------------------------------------
# Epoch 60/100, Iteration 4860, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: ن مرغ طر
# y:  مرغ طرب
# --------------------------------------------------
# Random Sample as text from   Validation
# x: � خوش �
# y:  خوش ک
# --------------------------------------------------
# Epoch 60/100, Validation Loss: 1.8262
# Epoch 61/100, Iteration 4865, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: م خوشتر
# y:  خوشتر
#
# --------------------------------------------------
# Epoch 61/100, Iteration 4870, Avg Loss: 0.0246
# Random Sample as text from   Training
# x: کار
# اف
# y: �ار
# افل
# --------------------------------------------------
# Epoch 61/100, Iteration 4875, Avg Loss: 0.0250
# Random Sample as text from   Training
# x:  ای سا�
# y: ای ساق
# --------------------------------------------------
# Epoch 61/100, Iteration 4880, Avg Loss: 0.0237
# Random Sample as text from   Training
# x: �ل و آداب
# y: ل و آداب �
# --------------------------------------------------
# Epoch 61/100, Iteration 4885, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: �و آرمی
# y: و آرمید
# --------------------------------------------------
# Epoch 61/100, Iteration 4890, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: ر مغاک م
# y:  مغاک من
# --------------------------------------------------
# Epoch 61/100, Iteration 4895, Avg Loss: 0.0260
# Random Sample as text from   Training
# x:  دستم نه
# y: �ستم نه
#
# --------------------------------------------------
# Epoch 61/100, Iteration 4900, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: بر پله �
# y: ر پله چ
# --------------------------------------------------
# Epoch 61/100, Iteration 4905, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: ابر به ن
# y: �ر به نو
# --------------------------------------------------
# Epoch 61/100, Iteration 4910, Avg Loss: 0.0247
# Random Sample as text from   Training
# x: لف نگا
# y: ف نگار
# --------------------------------------------------
# Epoch 61/100, Iteration 4915, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: ی غم فر
# y: � غم فرد
# --------------------------------------------------
# Epoch 61/100, Iteration 4920, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: �یر آخ
# y: یر آخر
# --------------------------------------------------
# Epoch 61/100, Iteration 4925, Avg Loss: 0.0253
# Random Sample as text from   Training
# x: �انی
# در
# y: انی
# در
# --------------------------------------------------
# Epoch 61/100, Iteration 4930, Avg Loss: 0.0272
# Random Sample as text from   Training
# x: شنیدی
# y: �نیدیم
# --------------------------------------------------
# Epoch 61/100, Iteration 4935, Avg Loss: 0.0258
# Random Sample as text from   Training
# x: �بینی �
# y: بینی ب
# --------------------------------------------------
# Epoch 61/100, Iteration 4940, Avg Loss: 0.0265
# Random Sample as text from   Training
# x: �مر ما چ
# y: مر ما چو
# --------------------------------------------------
# Random Sample as text from   Validation
# x: وش کن �
# y: ش کن ت
# --------------------------------------------------
# Epoch 61/100, Validation Loss: 1.7764
# Epoch 62/100, Iteration 4945, Avg Loss: 0.0188
# Random Sample as text from   Training
# x:
# با اهل �
# y: با اهل خ
# --------------------------------------------------
# Epoch 62/100, Iteration 4950, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: �
# از سل�
# y:
# از سلخ
# --------------------------------------------------
# Epoch 62/100, Iteration 4955, Avg Loss: 0.0246
# Random Sample as text from   Training
# x: ی بود آ
# y: � بود آن
# --------------------------------------------------
# Epoch 62/100, Iteration 4960, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: � کنند
# y:  کنند ا�
# --------------------------------------------------
# Epoch 62/100, Iteration 4965, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: � رخ گ
# y:  رخ گل
# --------------------------------------------------
# Epoch 62/100, Iteration 4970, Avg Loss: 0.0262
# Random Sample as text from   Training
# x: ر رهگذ
# y:  رهگذر
# --------------------------------------------------
# Epoch 62/100, Iteration 4975, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: رستان
# ج
# y: ستان
# ج�
# --------------------------------------------------
# Epoch 62/100, Iteration 4980, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: �یی با�
# y: یی باز
# --------------------------------------------------
# Epoch 62/100, Iteration 4985, Avg Loss: 0.0241
# Random Sample as text from   Training
# x: د دگر
# ن
# y:  دگر
# نن
# --------------------------------------------------
# Epoch 62/100, Iteration 4990, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: کس بودن
# y: �س بودن
#
# --------------------------------------------------
# Epoch 62/100, Iteration 4995, Avg Loss: 0.0255
# Random Sample as text from   Training
# x: هن گل
# ا
# y: ن گل
# ا�
# --------------------------------------------------
# Epoch 62/100, Iteration 5000, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: �یک آم
# y: یک آمد
# --------------------------------------------------
# Epoch 62/100, Iteration 5005, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: �ل خاک �
# y: ل خاک ش
# --------------------------------------------------
# Epoch 62/100, Iteration 5010, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: �شت
# بی
# y: شت
# بی�
# --------------------------------------------------
# Epoch 62/100, Iteration 5015, Avg Loss: 0.0247
# Random Sample as text from   Training
# x:  هفت شم
# y: �فت شمر
# --------------------------------------------------
# Epoch 62/100, Iteration 5020, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: �ازی ک
# y: ازی کر
# --------------------------------------------------
# Random Sample as text from   Validation
# x: ا
# حالی �
# y:
# حالی خ
# --------------------------------------------------
# Epoch 62/100, Validation Loss: 1.7976
# Epoch 63/100, Iteration 5025, Avg Loss: 0.0139
# Random Sample as text from   Training
# x: هی به
# م
# y: ی به
# مس
# --------------------------------------------------
# Epoch 63/100, Iteration 5030, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: � که بر
# y:  که بر�
# --------------------------------------------------
# Epoch 63/100, Iteration 5035, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: � بقا ز
# y:  بقا ز �
# --------------------------------------------------
# Epoch 63/100, Iteration 5040, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: �خت فر�
# y: خت فری
# --------------------------------------------------
# Epoch 63/100, Iteration 5045, Avg Loss: 0.0260
# Random Sample as text from   Training
# x: چو تو ب
# y: �و تو بو
# --------------------------------------------------
# Epoch 63/100, Iteration 5050, Avg Loss: 0.0251
# Random Sample as text from   Training
# x: کنون ک
# y: �نون که
# --------------------------------------------------
# Epoch 63/100, Iteration 5055, Avg Loss: 0.0257
# Random Sample as text from   Training
# x: � دست
# در
# y:  دست
# در �
# --------------------------------------------------
# Epoch 63/100, Iteration 5060, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: �دا غور
#
# y: دا غور
# �
# --------------------------------------------------
# Epoch 63/100, Iteration 5065, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: عل کن ب
# y: ل کن بل
# --------------------------------------------------
# Epoch 63/100, Iteration 5070, Avg Loss: 0.0256
# Random Sample as text from   Training
# x: ی
# از آم
# y: �
# از آمد
# --------------------------------------------------
# Epoch 63/100, Iteration 5075, Avg Loss: 0.0245
# Random Sample as text from   Training
# x:
# چندین
# y: چندین �
# --------------------------------------------------
# Epoch 63/100, Iteration 5080, Avg Loss: 0.0261
# Random Sample as text from   Training
# x: ر جویی
# y:  جویی �
# --------------------------------------------------
# Epoch 63/100, Iteration 5085, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: ک من و تو
# y: � من و تو
#
# --------------------------------------------------
# Epoch 63/100, Iteration 5090, Avg Loss: 0.0253
# Random Sample as text from   Training
# x: ی خور ت
# y: � خور تو
# --------------------------------------------------
# Epoch 63/100, Iteration 5095, Avg Loss: 0.0247
# Random Sample as text from   Training
# x: ا گفته
# y:  گفته
# --------------------------------------------------
# Epoch 63/100, Iteration 5100, Avg Loss: 0.0250
# Random Sample as text from   Training
# x: �ن گفت
# y: ن گفت �
# --------------------------------------------------
# Random Sample as text from   Validation
# x:
# حالی خ
# y: حالی خو
# --------------------------------------------------
# Epoch 63/100, Validation Loss: 1.8168
# Epoch 64/100, Iteration 5105, Avg Loss: 0.0098
# Random Sample as text from   Training
# x: �ساط باز
# y: ساط باز�
# --------------------------------------------------
# Epoch 64/100, Iteration 5110, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: و برم بر
# y:  برم بر�
# --------------------------------------------------
# Epoch 64/100, Iteration 5115, Avg Loss: 0.0238
# Random Sample as text from   Training
# x: گاری ب
# y: �اری بو
# --------------------------------------------------
# Epoch 64/100, Iteration 5120, Avg Loss: 0.0238
# Random Sample as text from   Training
# x: چه حجت
# y: �ه حجتم
# --------------------------------------------------
# Epoch 64/100, Iteration 5125, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: د بگذر
# y:  بگذرد
# --------------------------------------------------
# Epoch 64/100, Iteration 5130, Avg Loss: 0.0231
# Random Sample as text from   Training
# x:  نشود
# ت
# y: �شود
# تا
# --------------------------------------------------
# Epoch 64/100, Iteration 5135, Avg Loss: 0.0242
# Random Sample as text from   Training
# x: �هان نی
# y: هان نیس
# --------------------------------------------------
# Epoch 64/100, Iteration 5140, Avg Loss: 0.0263
# Random Sample as text from   Training
# x: رد مست
# چ
# y: د مست
# چن
# --------------------------------------------------
# Epoch 64/100, Iteration 5145, Avg Loss: 0.0259
# Random Sample as text from   Training
# x: ی و هست�
# y: � و هستی
# --------------------------------------------------
# Epoch 64/100, Iteration 5150, Avg Loss: 0.0247
# Random Sample as text from   Training
# x: � من و تو
#
# y:  من و تو
# �
# --------------------------------------------------
# Epoch 64/100, Iteration 5155, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: �ان می ب
# y: ان می ب�
# --------------------------------------------------
# Epoch 64/100, Iteration 5160, Avg Loss: 0.0253
# Random Sample as text from   Training
# x: �ل بزبا
# y: ل بزبان
# --------------------------------------------------
# Epoch 64/100, Iteration 5165, Avg Loss: 0.0253
# Random Sample as text from   Training
# x:  هست ز ه
# y: �ست ز هر
# --------------------------------------------------
# Epoch 64/100, Iteration 5170, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: دم که ج
# y: م که جا
# --------------------------------------------------
# Epoch 64/100, Iteration 5175, Avg Loss: 0.0254
# Random Sample as text from   Training
# x: سد چه ش
# y: د چه ش�
# --------------------------------------------------
# Epoch 64/100, Iteration 5180, Avg Loss: 0.0252
# Random Sample as text from   Training
# x:
# ز آن م�
# y: ز آن می
# --------------------------------------------------
# Random Sample as text from   Validation
# x: ا
# حالی �
# y:
# حالی خ
# --------------------------------------------------
# Epoch 64/100, Validation Loss: 1.8508
# Epoch 65/100, Iteration 5185, Avg Loss: 0.0050
# Random Sample as text from   Training
# x: نگ جرسه
# y: گ جرسها
# --------------------------------------------------
# Epoch 65/100, Iteration 5190, Avg Loss: 0.0246
# Random Sample as text from   Training
# x: د
# فریا�
# y:
# فریاد
# --------------------------------------------------
# Epoch 65/100, Iteration 5195, Avg Loss: 0.0253
# ...
# Epoch 95/100, Iteration 7630, Avg Loss: 0.0224
# Random Sample as text from   Training
# x: رگه آن �
# y: گه آن ش
# --------------------------------------------------
# Epoch 95/100, Iteration 7635, Avg Loss: 0.0232
# Random Sample as text from   Training
# x: ر چرخ �
# y:  چرخ ف
# --------------------------------------------------
# Epoch 95/100, Iteration 7640, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: �ز جام �
# y: ز جام ن
# --------------------------------------------------
# Epoch 95/100, Iteration 7645, Avg Loss: 0.0229
# Random Sample as text from   Training
# x: �می که
# y: می که �
# --------------------------------------------------
# Epoch 95/100, Iteration 7650, Avg Loss: 0.0225
# Random Sample as text from   Training
# x: ت در رو�
# y:  در روی
# --------------------------------------------------
# Epoch 95/100, Iteration 7655, Avg Loss: 0.0238
# Random Sample as text from   Training
# x: ز غم ن�
# y: � غم نف
# --------------------------------------------------
# Epoch 95/100, Iteration 7660, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: ر عاشق و
# y:  عاشق و م
# --------------------------------------------------
# Epoch 95/100, Iteration 7665, Avg Loss: 0.0235
# Random Sample as text from   Training
# x: ن که مه�
# y:  که مهی
# --------------------------------------------------
# Epoch 95/100, Iteration 7670, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: ک او ن�
# y: � او نظ
# --------------------------------------------------
# Epoch 95/100, Iteration 7675, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: �رد
# ابر
# y: رد
# ابر ا�
# --------------------------------------------------
# Epoch 95/100, Iteration 7680, Avg Loss: 0.0238
# Random Sample as text from   Training
# x:  قدحی �
# y: �دحی ب
# --------------------------------------------------
# Epoch 95/100, Iteration 7685, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: نی بوده
# y: ی بوده
# --------------------------------------------------
# Epoch 95/100, Iteration 7690, Avg Loss: 0.0231
# Random Sample as text from   Training
# x:  محدث �
# y: حدث چ
# --------------------------------------------------
# Epoch 95/100, Iteration 7695, Avg Loss: 0.0242
# Random Sample as text from   Training
# x: ه باشی �
# y:  باشی ه
# --------------------------------------------------
# Random Sample as text from   Validation
# x: �ا
# حالی
# y: ا
# حالی �
# --------------------------------------------------
# Epoch 95/100, Validation Loss: 1.9366
# Epoch 96/100, Iteration 7700, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: ندر دست
#
# y: در دست
# ن
# --------------------------------------------------
# Epoch 96/100, Iteration 7705, Avg Loss: 0.0222
# Random Sample as text from   Training
# x:  و بتی و �
# y:  بتی و ب
# --------------------------------------------------
# Epoch 96/100, Iteration 7710, Avg Loss: 0.0241
# Random Sample as text from   Training
# x: �زم رح
# y: زم رح�
# --------------------------------------------------
# Epoch 96/100, Iteration 7715, Avg Loss: 0.0241
# Random Sample as text from   Training
# x:  که بی
# y: که بی�
# --------------------------------------------------
# Epoch 96/100, Iteration 7720, Avg Loss: 0.0233
# Random Sample as text from   Training
# x: �یز ک
# y: یز که
# --------------------------------------------------
# Epoch 96/100, Iteration 7725, Avg Loss: 0.0240
# Random Sample as text from   Training
# x:  چه دان
# y: چه داند
# --------------------------------------------------
# Epoch 96/100, Iteration 7730, Avg Loss: 0.0239
# Random Sample as text from   Training
# x: �ن تازه �
# y: ن تازه ب
# --------------------------------------------------
# Epoch 96/100, Iteration 7735, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: �ود ترا م
# y: ود ترا م�
# --------------------------------------------------
# Epoch 96/100, Iteration 7740, Avg Loss: 0.0239
# Random Sample as text from   Training
# x: �ین که
# y: ین که �
# --------------------------------------------------
# Epoch 96/100, Iteration 7745, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: ن عزم د
# y:  عزم در
# --------------------------------------------------
# Epoch 96/100, Iteration 7750, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: ام خوانن
# y: م خوانند
# --------------------------------------------------
# Epoch 96/100, Iteration 7755, Avg Loss: 0.0252
# Random Sample as text from   Training
# x: که وامان
# y: �ه واماند
# --------------------------------------------------
# Epoch 96/100, Iteration 7760, Avg Loss: 0.0247
# Random Sample as text from   Training
# x:  ز نیک
# y: � نیک و
# --------------------------------------------------
# Epoch 96/100, Iteration 7765, Avg Loss: 0.0238
# Random Sample as text from   Training
# x:  می که �
# y: ی که ن
# --------------------------------------------------
# Epoch 96/100, Iteration 7770, Avg Loss: 0.0241
# Random Sample as text from   Training
# x:  گل
# ای
# y: گل
# ای �
# --------------------------------------------------
# Epoch 96/100, Iteration 7775, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: ه خواری
# y:  خواری �
# --------------------------------------------------
# Random Sample as text from   Validation
# x:  خوش ک
# y: �وش کن
# --------------------------------------------------
# Epoch 96/100, Validation Loss: 1.9153
# Epoch 97/100, Iteration 7780, Avg Loss: 0.0183
# Random Sample as text from   Training
# x: ه نمی آ
# y:  نمی آ�
# --------------------------------------------------
# Epoch 97/100, Iteration 7785, Avg Loss: 0.0231
# Random Sample as text from   Training
# x: رخ دید
# y: خ دیدم
# --------------------------------------------------
# Epoch 97/100, Iteration 7790, Avg Loss: 0.0238
# Random Sample as text from   Training
# x:  بنشین
# y: �نشین
# --------------------------------------------------
# Epoch 97/100, Iteration 7795, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: ر که فل
# y:  که فل�
# --------------------------------------------------
# Epoch 97/100, Iteration 7800, Avg Loss: 0.0229
# Random Sample as text from   Training
# x: ی چرا �
# y: � چرا ب
# --------------------------------------------------
# Epoch 97/100, Iteration 7805, Avg Loss: 0.0241
# Random Sample as text from   Training
# x: گوید
# �
# y: �وید
# ی
# --------------------------------------------------
# Epoch 97/100, Iteration 7810, Avg Loss: 0.0231
# Random Sample as text from   Training
# x: و آب زند
# y:  آب زند�
# --------------------------------------------------
# Epoch 97/100, Iteration 7815, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: ت
# دریا�
# y:
# دریاف
# --------------------------------------------------
# Epoch 97/100, Iteration 7820, Avg Loss: 0.0232
# Random Sample as text from   Training
# x:
# ور نی�
# y: ور نیز
# --------------------------------------------------
# Epoch 97/100, Iteration 7825, Avg Loss: 0.0236
# Random Sample as text from   Training
# x: � می ناب
# y:  می ناب
# --------------------------------------------------
# Epoch 97/100, Iteration 7830, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: ا صنمی
# y:  صنمی ل
# --------------------------------------------------
# Epoch 97/100, Iteration 7835, Avg Loss: 0.0249
# Random Sample as text from   Training
# x: کیم هم
# y: �یم همه
# --------------------------------------------------
# Epoch 97/100, Iteration 7840, Avg Loss: 0.0236
# Random Sample as text from   Training
# x:  باشی ه
# y: �اشی هم
# --------------------------------------------------
# Epoch 97/100, Iteration 7845, Avg Loss: 0.0234
# Random Sample as text from   Training
# x: آمد مگس
# y: �مد مگس�
# --------------------------------------------------
# Epoch 97/100, Iteration 7850, Avg Loss: 0.0243
# Random Sample as text from   Training
# x: هار زند�
# y: ار زندگ
# --------------------------------------------------
# Epoch 97/100, Iteration 7855, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: ین عمر �
# y: �ن عمر ب
# --------------------------------------------------
# Random Sample as text from   Validation
# x: وش کن �
# y: ش کن ت
# --------------------------------------------------
# Epoch 97/100, Validation Loss: 1.9399
# Epoch 98/100, Iteration 7860, Avg Loss: 0.0140
# Random Sample as text from   Training
# x:
# فارغ �
# y: فارغ ب
# --------------------------------------------------
# Epoch 98/100, Iteration 7865, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: شسته بر
# y: �سته بر �
# --------------------------------------------------
# Epoch 98/100, Iteration 7870, Avg Loss: 0.0229
# Random Sample as text from   Training
# x:  بیهوده
# y: �یهوده م
# --------------------------------------------------
# Epoch 98/100, Iteration 7875, Avg Loss: 0.0241
# Random Sample as text from   Training
# x: دیده اس
# y: یده است
# --------------------------------------------------
# Epoch 98/100, Iteration 7880, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: اران به م
# y: ران به مو
# --------------------------------------------------
# Epoch 98/100, Iteration 7885, Avg Loss: 0.0240
# Random Sample as text from   Training
# x:  خویش �
# y: �ویش ر
# --------------------------------------------------
# Epoch 98/100, Iteration 7890, Avg Loss: 0.0232
# Random Sample as text from   Training
# x: ی و دمی
# y: � و دمی
# --------------------------------------------------
# Epoch 98/100, Iteration 7895, Avg Loss: 0.0232
# Random Sample as text from   Training
# x: �ام باده
# y: ام باده
# --------------------------------------------------
# Epoch 98/100, Iteration 7900, Avg Loss: 0.0245
# Random Sample as text from   Training
# x: ه یکی
# y:  یکی
# --------------------------------------------------
# Epoch 98/100, Iteration 7905, Avg Loss: 0.0227
# Random Sample as text from   Training
# x:  زمین و
# y: �مین و �
# --------------------------------------------------
# Epoch 98/100, Iteration 7910, Avg Loss: 0.0238
# Random Sample as text from   Training
# x: �دان
# برد
# y: دان
# بردا�
# --------------------------------------------------
# Epoch 98/100, Iteration 7915, Avg Loss: 0.0233
# Random Sample as text from   Training
# x:  زلفین
# y: �لفین
# --------------------------------------------------
# Epoch 98/100, Iteration 7920, Avg Loss: 0.0251
# Random Sample as text from   Training
# x: �دان مشو
# y: دان مشو
# --------------------------------------------------
# Epoch 98/100, Iteration 7925, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: هان هست م
# y: ان هست م�
# --------------------------------------------------
# Epoch 98/100, Iteration 7930, Avg Loss: 0.0232
# Random Sample as text from   Training
# x: زیر ی
# y: �یر یا
# --------------------------------------------------
# Epoch 98/100, Iteration 7935, Avg Loss: 0.0241
# Random Sample as text from   Training
# x:  و کف �
# y:  کف ک
# --------------------------------------------------
# Random Sample as text from   Validation
# x: �وش کن
# y: وش کن �
# --------------------------------------------------
# Epoch 98/100, Validation Loss: 1.9351
# Epoch 99/100, Iteration 7940, Avg Loss: 0.0094
# Random Sample as text from   Training
# x: ه بیار
# y:  بیار ا
# --------------------------------------------------
# Epoch 99/100, Iteration 7945, Avg Loss: 0.0236
# Random Sample as text from   Training
# x: ناک شده
# y: اک شده
#
# --------------------------------------------------
# Epoch 99/100, Iteration 7950, Avg Loss: 0.0226
# Random Sample as text from   Training
# x: اق وجود
# y: ق وجود م
# --------------------------------------------------
# Epoch 99/100, Iteration 7955, Avg Loss: 0.0244
# Random Sample as text from   Training
# x: �فتی
# م
# y: فتی
# م�
# --------------------------------------------------
# Epoch 99/100, Iteration 7960, Avg Loss: 0.0236
# Random Sample as text from   Training
# x:  مراد ران
# y: راد راند
# --------------------------------------------------
# Epoch 99/100, Iteration 7965, Avg Loss: 0.0239
# Random Sample as text from   Training
# x:  از رخ �
# y: از رخ آ
# --------------------------------------------------
# Epoch 99/100, Iteration 7970, Avg Loss: 0.0237
# Random Sample as text from   Training
# x: ه گری
# y:  گری �
# --------------------------------------------------
# Epoch 99/100, Iteration 7975, Avg Loss: 0.0237
# Random Sample as text from   Training
# x: ی زمین
# y: � زمین�
# --------------------------------------------------
# Epoch 99/100, Iteration 7980, Avg Loss: 0.0233
# Random Sample as text from   Training
# x: �هر ناپ
# y: هر ناپ�
# --------------------------------------------------
# Epoch 99/100, Iteration 7985, Avg Loss: 0.0242
# Random Sample as text from   Training
# x: د
# این �
# y:
# این ک
# --------------------------------------------------
# Epoch 99/100, Iteration 7990, Avg Loss: 0.0238
# Random Sample as text from   Training
# x: ثالی دا
# y: �الی دان
# --------------------------------------------------
# Epoch 99/100, Iteration 7995, Avg Loss: 0.0235
# Random Sample as text from   Training
# x: ایره ب�
# y: یره بی
# --------------------------------------------------
# Epoch 99/100, Iteration 8000, Avg Loss: 0.0242
# Random Sample as text from   Training
# x: زی رو�
# y: �ی روز
# --------------------------------------------------
# Epoch 99/100, Iteration 8005, Avg Loss: 0.0239
# Random Sample as text from   Training
# x:  بساز
# ک
# y: �ساز
# کا
# --------------------------------------------------
# Epoch 99/100, Iteration 8010, Avg Loss: 0.0239
# Random Sample as text from   Training
# x: �سته که
# y: سته که �
# --------------------------------------------------
# Epoch 99/100, Iteration 8015, Avg Loss: 0.0232
# Random Sample as text from   Training
# x: � کی ش
# y:  کی شد
# --------------------------------------------------
# Random Sample as text from   Validation
# x: وش کن �
# y: ش کن ت
# --------------------------------------------------
# Epoch 99/100, Validation Loss: 1.9187
# Epoch 100/100, Iteration 8020, Avg Loss: 0.0048
# Random Sample as text from   Training
# x: ت
# می لع
# y:
# می لعل
# --------------------------------------------------
# Epoch 100/100, Iteration 8025, Avg Loss: 0.0228
# Random Sample as text from   Training
# x: است دگر
# y: �ت دگر �
# --------------------------------------------------
# Epoch 100/100, Iteration 8030, Avg Loss: 0.0232
# Random Sample as text from   Training
# x: وین
# ی�
# y: ین
# یک
# --------------------------------------------------
# Epoch 100/100, Iteration 8035, Avg Loss: 0.0235
# Random Sample as text from   Training
# x: رفتیم �
# y: فتیم ب
# --------------------------------------------------
# Epoch 100/100, Iteration 8040, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: و سه پی
# y:  سه پی�
# --------------------------------------------------
# Epoch 100/100, Iteration 8045, Avg Loss: 0.0239
# Random Sample as text from   Training
# x: �ادیم و �
# y: ادیم و ن
# --------------------------------------------------
# Epoch 100/100, Iteration 8050, Avg Loss: 0.0238
# Random Sample as text from   Training
# x: نی به �
# y: ی به ک
# --------------------------------------------------
# Epoch 100/100, Iteration 8055, Avg Loss: 0.0250
# Random Sample as text from   Training
# x:
# میترسم
# y: میترسم
# --------------------------------------------------
# Epoch 100/100, Iteration 8060, Avg Loss: 0.0236
# Random Sample as text from   Training
# x: گرفتند
# y: �رفتند
# --------------------------------------------------
# Epoch 100/100, Iteration 8065, Avg Loss: 0.0248
# Random Sample as text from   Training
# x: �تر رز �
# y: تر رز ر
# --------------------------------------------------
# Epoch 100/100, Iteration 8070, Avg Loss: 0.0240
# Random Sample as text from   Training
# x: چنان ک
# y: �نان که
# --------------------------------------------------
# Epoch 100/100, Iteration 8075, Avg Loss: 0.0251
# Random Sample as text from   Training
# x: � نتوانم
# y:  نتوانم
#
# --------------------------------------------------
# Epoch 100/100, Iteration 8080, Avg Loss: 0.0234
# Random Sample as text from   Training
# x: �س بودن
#
# y: س بودن
# ب
# --------------------------------------------------
# Epoch 100/100, Iteration 8085, Avg Loss: 0.0243
# Random Sample as text from   Training
# x: �بر دو �
# y: بر دو گ
# --------------------------------------------------
# Epoch 100/100, Iteration 8090, Avg Loss: 0.0229
# Random Sample as text from   Training
# x: و پیراه
# y:  پیراهن
# --------------------------------------------------
# Epoch 100/100, Iteration 8095, Avg Loss: 0.0234
# Random Sample as text from   Training
# x: ز مکن ز
# y: � مکن ز
# --------------------------------------------------
# Epoch 100/100, Iteration 8100, Avg Loss: 0.0239
# Random Sample as text from   Training
# x: � کینه
# y:  کینه �
# --------------------------------------------------
# Random Sample as text from   Validation
# x: �ا
# حالی
# y: ا
# حالی �
# --------------------------------------------------
# Epoch 100/100, Validation Loss: 1.9580
